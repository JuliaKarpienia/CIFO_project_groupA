# %%
import pandas as pd
from collections import defaultdict
from Operators.evaluation import *

# %%
fitness_path = "fitness_logs_elit"
summary_path = "ga_summary_elit.csv"

# %%
fitness_dfs = load_fitness_logs(fitness_path)
# Out:
# Loaded 24 configurations from 'fitness_logs_elit'

# %%
fitness_dfs.keys()
# Out:
# dict_keys(['POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=False', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=True', 'POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=False'])

# %%
plot_median_fitness_over_gen(fitness_dfs)

# %%
plot_median_fitness_by_operator(fitness_path)

# %% [markdown]
# ## Statistical tests

# %% [markdown]
# #### The Friedman test, checks if there’s any significant difference across all configurations,
# #### <br> If there are significant difference then  apply the Nemenyi post-hoc test, which compares each pair of configurations

# %% [markdown]
#  Friedman Test (non-parametric ANOVA for repeated measures)

# %% [markdown]
# Use when: You want to compare 3 or more configurations across repeated runs (e.g., different crossover strategies).
#
# Assumption: Repeated measurements across same conditions.
#
# Output: Tells you if there is a statistically significant difference somewhere in the group.

# %% [markdown]
# ### Evaluating statistical significance across full hyperparameter configurations
# Constraints:
# * Same dataset: All configurations are tested on the same dataset
# * Same number of runs: Each configuration must have the same number of runs (30)
# * Same evaluation metric:  final fitness from each run
#
# Null hypothesis (H₀): All configurations perform equally (no statistically significant difference in performance).
#
# If p < 0.05: You can reject H₀ — at least one configuration performs significantly differently.

# %%
labels, results = run_friedman_test_on_best_fitness(fitness_dfs)
# Out:
# Friedman Test Results:
# Test Statistic: 373.8070
# P-value:        0.0000
# Significant difference detected between configurations (reject H₀)

# %%
posthoc_results = run_posthoc_nemenyi_from_best_fitness(labels, results)
# Out:
# Post-hoc Nemenyi Test (p-values):
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9829
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9606
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.1641
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0021
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9796
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.7232
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.6395
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9977
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9829
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9933
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9993
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9922
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.5662
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8753
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0003
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9422
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0360
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9992
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0213
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8753
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8753
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.1681
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.1153
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9933
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9818
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.2268
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0037
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9917
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.8098
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.7364
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9994
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0002
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=True  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9606
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9818
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9999
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9796
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.6751
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.7984
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0006
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8923
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0571
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9971
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0002
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0349
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.7984
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.7984
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.2369
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.1681
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.1641
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9993
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.2268
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9999
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.2169
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9995
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0522
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0982
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.8753
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0904
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8154
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.3798
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9928
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0435
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.7165
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0522
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0522
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0236
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9839
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9626
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_whole_position selection_alg=tournament_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9922
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9796
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.2169
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0034
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9904
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.7984
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.7232
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9992
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0002
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0021
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.5662
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0037
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.6751
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0034
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.5883
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9448
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0004
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8616
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9697
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.1064
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0008
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0099
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.3665
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.6960
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9999
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0004
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0004
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.5588
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9796
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9917
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9995
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9904
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.5883
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8616
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0004
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9339
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0396
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9990
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0236
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8616
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8616
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.1806
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.1246
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=full_position_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=True  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.7232
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.8098
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.7984
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9448
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.4209
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0054
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9996
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.5588
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.2318
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9247
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0018
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.1602
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.4209
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.4209
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0008
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.5957
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.4852
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_swap_2teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=True  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.8753
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.7984
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0522
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# ...
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_whole_position selection_alg=roulette_selection elitism=False  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0236
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.5588
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0008
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0013
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9977
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9995
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9309
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9663
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_extreme_player selection_alg=roulette_selection elitism=True  \
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.1681
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0002
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.2369
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9839
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0002
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.1806
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.5957
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9957
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.6822
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0141
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0007
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0809
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9728
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9309
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
#
#                                                     POP=100 XO=0.9 mut_prob=0.1 mutation=single_player_shift_all_teams crossover=crossover_swap_extreme_player selection_alg=tournament_selection elitism=False
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.1153
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.1681
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.9626
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0001
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.1246
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.4852
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9988
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.5735
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0082
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0004
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                                             0.0522
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9891
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             0.9663
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                                             1.0000
#
# [24 rows x 24 columns]

# %%
plot_posthoc_heatmap(posthoc_results)
# Out:
# /Users/juliakarpienia/Desktop/NOVA IMS /2nd sem/CIFO/CIFO_project_groupA/Operators/evaluation.py:281: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
summarize_significant_wins(posthoc_results)
# Out:
#                                                     Significant Wins
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                16
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                16
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                15
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                13
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                12
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 9
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 9
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=single_pla...                 8
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 7
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 5
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 5
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 5
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 4
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 3
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 3
# POP=100 XO=0.9 mut_prob=0.1 mutation=full_posit...                 2

# %% [markdown]
# The table gives a ranking based not just on performance, but on statistical confidence:
# <br> Higher "Significant Wins" → more robust evidence that this configuration is truly better across multiple comparisons.
# <br> Helps avoid picking a config just because of random variation in performance.

# %% [markdown]
# Config 1: It significantly beat 16 other configurations (with p < 0.05 in the Nemenyi test),
# This suggests it’s a strong candidate for the best hyperparameter setup.

# %% [markdown]
# | POP | XO  | Mut Prob | Mutation                     | Crossover             | Selection Alg         | Elitism | Significant Wins | Interpretation                                                                 |
# | --- | --- | -------- | ---------------------------- | --------------------- | --------------------- | ------- | ---------------- | ------------------------------------------------------------------------------ |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_whole\_position | roulette\_selection   | False   | **16**           | Best performer without elitism; shows strong performance without preservation. |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_whole\_position | tournament\_selection | True    | **16**           | Same setup as above but with elitism; equally strong performance.              |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_whole\_position | roulette\_selection   | True    | 15               | Slight drop but still excellent with elitism.                                  |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_whole\_position | tournament\_selection | False   | 13               | Still competitive, though weaker without elitism.                              |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_extreme\_player | tournament\_selection | True    | 12               | Performs well with elitism and alternative crossover.                          |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_extreme\_player | tournament\_selection | False   | 9                | Slightly weaker without elitism.                                               |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_extreme\_player | roulette\_selection   | True    | 9                | Consistent with elitism; crossover still effective.                            |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_extreme\_player | tournament\_selection | True    | 8                | Good combo with elitism.                                                       |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_extreme\_player | roulette\_selection   | False   | 8                | Solid result even without elitism.                                             |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_extreme\_player | roulette\_selection   | True    | 8                | Very robust combo across selection types.                                      |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_whole\_position | tournament\_selection | True    | 8                | Reliable performance with elitism.                                             |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_extreme\_player | tournament\_selection | False   | 8                | Maintains strength across selection methods.                                   |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_whole\_position | roulette\_selection   | True    | 8                | Consistently high performer with elitism.                                      |
# | 100 | 0.9 | 0.1      | shift\_all\_teams            | swap\_extreme\_player | roulette\_selection   | False   | 8                | Holds up well without elitism.                                                 |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_whole\_position | tournament\_selection | False   | 8                | Balanced and adaptable combo.                                                  |
# | 100 | 0.9 | 0.1      | swap\_2teams                 | swap\_whole\_position | roulette\_selection   | False   | 8                | Good baseline setup.                                                           |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_extreme\_player | roulette\_selection   | False   | 7                | Acceptable performance but weaker than swap/shift mutations.                   |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_extreme\_player | tournament\_selection | False   | 5                | Drop in performance, especially without elitism.                               |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_extreme\_player | roulette\_selection   | True    | 5                | Slight recovery with elitism.                                                  |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_whole\_position | roulette\_selection   | False   | 5                | Fair, but not top-tier performer.                                              |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_whole\_position | tournament\_selection | True    | 4                | Below average despite elitism.                                                 |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_extreme\_player | tournament\_selection | True    | 3                | One of the weakest configurations tested.                                      |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_whole\_position | roulette\_selection   | True    | 3                | Doesn’t benefit much from elitism.                                             |
# | 100 | 0.9 | 0.1      | full\_position\_swap\_2teams | swap\_whole\_position | tournament\_selection | False   | 2                | Lowest performing; weak across all settings.                                   |

# %% [markdown]
# ### Analyzing only the best-performing configurations from slim_summary.csv

# %%
plot_top_configs(summary_path=summary_path,fitness_log_folder=fitness_path, top_n=5, metric='median_fitness')

# %%
plot_top_configs(summary_path=summary_path,fitness_log_folder=fitness_path, top_n=5, metric="std_fitness")

# %%
plot_best_fitness_boxplot()
# Out:
# /Users/juliakarpienia/Desktop/NOVA IMS /2nd sem/CIFO/CIFO_project_groupA/Operators/evaluation.py:214: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
